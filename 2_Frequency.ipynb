# %% [markdown]
# # Frequency by depth plots
#
# drilling induced damage
# fracture frequency
# fracture by aperture

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# make a list of depths from 0 to 1000 m that are randomly spaced
depths = np.random.randint(0, 1000, 1000)

# make a list of widths from 0 to 10 mm that are randomly spaced 
widths = np.random.randint(0, 10, 1000)

# use the subplots method plot depths on the y axis and widths on the x with a reversed y axis
fig, ax = plt.subplots()
ax.scatter(widths, depths)
ax.set_ylim(ax.get_ylim()[::-1])
# Out:
# (1048.95, -49.95)
